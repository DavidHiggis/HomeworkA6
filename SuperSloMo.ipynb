# %% [markdown]
# # Slow Motion with Super SloMo
#
# This notebook uses [Super SloMo](https://arxiv.org/abs/1712.00080) from the open source project [avinashpaliwal/Super-SloMo](https://github.com/avinashpaliwal/Super-SloMo) to slow down a given youtube video.
#
# For other deep-learning Colab notebooks, visit [tugstugi/dl-colab-notebooks](https://github.com/tugstugi/dl-colab-notebooks).
#
#
# ## Install avinashpaliwal/Super-SloMo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/TFMLz/slomo
# Out:
# /content/drive/My Drive/TFMLz/slomo

# %%
import os
from os.path import exists, join, basename, splitext, dirname
# !pip install -q youtube-dl
# !git clone https://github.com/avinashpaliwal/Super-SloMo.git

import sys
from IPython.display import YouTubeVideo
# Out:
#      |████████████████████████████████| 1.8MB 4.8MB/s
# Cloning into 'Super-SloMo'...
# remote: Enumerating objects: 174, done.
# remote: Total 174 (delta 0), reused 0 (delta 0), pack-reused 174
# Receiving objects: 100% (174/174), 26.88 MiB | 21.07 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %% [markdown]
# ## Super SloMo on a Youtube Video
#
# We are going to slow down first 5 seconds of the following youtube video:

# %% [markdown]
# Download the above video and slow down 3x times the first 5 seconds:

# %%
SLOW_MOTION_FACTOR = 3
TARGET_FPS = 90

ffmpeg_path = !which ffmpeg
ffmpeg_path = dirname(ffmpeg_path[0])

# !rm -df youtube.mp4
# download the youtube with the given ID
# !youtube-dl -f 'bestvideo[ext=mp4]' --output "/content/sample_data/youtube.%(ext)s" http://www.youtube.com/watch?v=YOpgRG1Mhdw
# cut the first 5 seconds
#!ffmpeg -y -loglevel info -i /content/sample_data/youtube.mp4 -t 5 /content/sample_data/video.mp4

# !python video_to_slomo.py --ffmpeg {ffmpeg_path} --checkpoint SuperSloMo.ckpt --video /content/sample_data/youtube.mp4 --sf {SLOW_MOTION_FACTOR} --fps {TARGET_FPS} --output /content/sample_data/output.mkv

# %% [markdown]
# Finally, visualize the result:

# %%
def show_local_mp4_video(file_name, width=640, height=480):
  import io
  import base64
  from IPython.display import HTML
  video_encoded = base64.b64encode(io.open(file_name, 'rb').read())
  return HTML(data='''<video width="{0}" height="{1}" alt="test" controls>
                        <source src="data:video/mp4;base64,{2}" type="video/mp4" />
                      </video>'''.format(width, height, video_encoded.decode('ascii')))

show_local_mp4_video('output.mp4', width=960, height=720)
